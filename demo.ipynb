# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import robo_jockey as rj

# %%
df = pd.read_csv("data/data_cleaned.csv")

# %%
songs_df = df.sample(50)

# %%
playlist_df = rj.generate_playlist(songs_df,10)
# Out:
# Choose the vibe! Ebb-and-flow (1 / default) or The-sky-is-the-limit (2): 2

# %%
# visual test (case 1)

import matplotlib.pyplot as plt

playlist_scores = list(playlist_df.party_score)
plt.plot(playlist_scores)
plt.scatter(range(len(playlist_scores)),playlist_scores,c="red")
plt.xticks([])
plt.xlabel("Song's index in playlist")
plt.ylabel("party_score")
plt.title("Time evolution of playlist's party_score variable")
plt.show()

# %%
# visual test (case 2)

import matplotlib.pyplot as plt

playlist_scores = list(playlist_df.party_score)
plt.plot(playlist_scores)
plt.scatter(range(len(playlist_scores)),playlist_scores,c="red")
plt.xticks([])
plt.xlabel("Song's index in playlist")
plt.ylabel("party_score")
plt.title("Time evolution of playlist's party_score variable")
plt.show()
